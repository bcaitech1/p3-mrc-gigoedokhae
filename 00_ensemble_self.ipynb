# %% [markdown]
# ## 1. Load Data

# %%
import json

def get_preds(path):
    with open(path) as f:
        return json.load(f) # dict

path = "/opt/ml/outputs/preds/backup/no1_xlm_roberta/nbest_predictions.json"
preds = get_preds(path)

# %% [markdown]
# ## -1. Save (ensemble result)

# %%
from utils import increment_path

def save_json(preds, path):
    with open(path, "w") as f:
            f.write(json.dumps(preds, indent=4, ensure_ascii=False) + "\n")

out_path = increment_path("/opt/ml/outputs/preds/", infix="ensemble", name="predictions.json")
save_json(ensemble_result, out_path)

# %% [markdown]
# ## 2-1. Sum ensemble

# %%
from collections import defaultdict
from operator import itemgetter


def _get_text_scores(ans_list):
    text_scores = defaultdict(float)
    for ans in ans_list:
        text_scores[ans["text"]] += ans["probability"]
    return text_scores

def _get_best_text(text_scores):
    return max(text_scores.items(), key=itemgetter(1))[0]

def get_self_ensemble_result(preds: dict):
    result = dict() # dict keeps input sequence order
    for q_id, ans_list in preds.items():
        text_scores = _get_text_scores(ans_list)
        best_text = _get_best_text(text_scores)
        result[q_id] = best_text
        
    return result

ensemble_result = get_self_ensemble_result(preds)
#ensemble_result

# %% [markdown]
# ## 2-2. Count ensemble

# %%
from collections import defaultdict
from operator import itemgetter


def _get_text_counts(ans_list):
    text_counts = defaultdict(int)
    for ans in ans_list:
        text_counts[ans["text"]] += 1
    return text_counts

def _get_best_text(text_counts):
    return max(text_counts.items(), key=itemgetter(1))[0]

def get_self_ensemble_result(preds: dict):
    result = dict() # dict keeps input sequence order
    for q_id, ans_list in preds.items():
        text_counts = _get_text_counts(ans_list)
        best_text = _get_best_text(text_counts)
        result[q_id] = best_text
        
    return result

ensemble_result = get_self_ensemble_result(preds)
#ensemble_result

# %% [markdown]
# ## 2-3. Sum*Count ensemble

# %%
from collections import defaultdict
from operator import itemgetter

def _get_text_counts(ans_list):
    text_counts = defaultdict(int)
    for ans in ans_list:
        text_counts[ans["text"]] += 1
    return text_counts

def _get_text_scores(ans_list):
    text_scores = defaultdict(float)
    for ans in ans_list:
        text_scores[ans["text"]] += ans["probability"]
    return text_scores

def _get_best_text(text_scores):
    return max(text_scores.items(), key=itemgetter(1))[0]

def get_self_ensemble_result(preds: dict, exp=1.0):
    result = dict() # dict keeps input sequence order
    for q_id, ans_list in preds.items():
        text_scores = _get_text_scores(ans_list)
        text_counts = _get_text_counts(ans_list)
        text_weighted_scores = {text: score*(count**exp) for text, score, count in zip(text_scores, text_scores.values(), text_counts.values())}
        best_text = _get_best_text(text_weighted_scores)
        result[q_id] = best_text
        
    return result

ensemble_result = get_self_ensemble_result(preds, exp=1)
ensemble_result
# Out:
# {'mrc-1-000653': '지구',
#  'mrc-1-001113': '플레이오프',
#  'mrc-0-002191': '빌헬름 미클라스',
#  'mrc-0-003951': '뉴질랜드',
#  'mrc-1-001272': '북한군',
#  'mrc-1-000993': '아래턱',
#  'mrc-0-005021': '근대 자본주의',
#  'mrc-1-000163': '인격성',
#  'mrc-0-001283': '순조 11년(1811)',
#  'mrc-0-004543': '고전도성 철',
#  'mrc-0-000439': '점쟁이',
#  'mrc-0-002895': '칼라치 전방 약250km 지점',
#  'mrc-0-000535': '롭 포드',
#  'mrc-1-001724': '〈상당(上堂)〉',
#  'mrc-0-000901': '고려 현종',
#  'mrc-0-001606': '그로인볼트',
#  'mrc-0-000266': '공무원',
#  'mrc-0-001326': '《코믹 바이어스 가이드》',
#  'mrc-0-000032': '국방부 보고서',
#  'mrc-0-005215': '영산사',
#  'mrc-0-005407': '숙의 정씨',
#  'mrc-0-003683': '국가인권위원회',
#  'mrc-0-003644': '이탈리아',
#  'mrc-0-002835': '바이샬리',
#  'mrc-0-000049': '아이템',
#  'mrc-1-001829': '화흡',
#  'mrc-1-001662': '보신 전쟁',
#  'mrc-0-001206': '2018년',
#  'mrc-0-004007': '로스쿨',
#  'mrc-1-000418': '일등바위',
#  'mrc-0-003133': '잡화점',
#  'mrc-0-004646': '건늠선',
#  'mrc-0-001058': '카필라 성',
#  'mrc-0-002361': '종가의 자존심',
#  'mrc-0-004830': '13개',
#  'mrc-0-002762': '‘남고사’',
#  'mrc-0-000395': '오달제',
#  'mrc-0-001668': '어머니',
#  'mrc-0-004487': '상어 공격 전문가',
#  'mrc-0-001086': '라이프치히',
#  'mrc-0-004413': '호어벨리샤',
#  'mrc-1-000221': '나무',
#  'mrc-0-002177': '시트로엥',
#  'mrc-0-003223': '김연철',
#  'mrc-0-000624': '영국',
#  'mrc-0-004318': '1943년 7월 2일',
#  'mrc-0-002764': '카에데 소이치로(소리마치 타카시)',
#  'mrc-0-001725': '스털링 실리펀트',
#  'mrc-0-004445': '2019년 8월 1일',
#  'mrc-0-000001': '강연옥',
#  'mrc-0-005411': '사비나',
#  'mrc-1-001280': '미국 대통령 우드로 윌슨',
#  'mrc-0-003385': '후한 말기',
#  'mrc-1-001555': '도야마 상업고등학교',
#  'mrc-0-000854': '1935년',
#  'mrc-0-000504': '고려초기',
#  'mrc-0-000988': '노포탑(露砲塔)',
#  'mrc-0-003763': '전면',
#  'mrc-1-001619': '모리 오가이',
#  'mrc-0-004880': '북아메리카의 캘리포니아 기지의 강탈이었다. 연방군에 있어 남미 자브',
#  'mrc-0-003177': '연금',
#  'mrc-1-001523': '윤창구',
#  'mrc-1-001353': '애굽',
#  'mrc-0-005278': '근세',
#  'mrc-0-003896': '루돌프 클라인-바싱크',
#  'mrc-0-000339': '시칠리아',
#  'mrc-0-001183': '러더퍼드 B. 헤이스',
#  'mrc-1-001155': '광고',
#  'mrc-0-000991': '윌리엄 3세',
#  'mrc-0-005328': '신라 때',
#  'mrc-0-002070': '압력',
#  'mrc-0-003298': '오카다 다케시',
#  'mrc-0-002453': '요미우리',
#  'mrc-0-003274': '필라델피아',
#  'mrc-0-004430': '돈',
#  'mrc-0-003455': '스포츠 신문',
#  'mrc-0-003628': '공유 필명',
#  'mrc-0-000432': '조선건국동맹',
#  'mrc-0-000540': '오라 캐넌',
#  'mrc-0-000607': '비정상적으로 큰 송곳니',
#  'mrc-0-003540': '해상 교통, 보급 확보에 충당해야 할 함정과 인력의 부족',
#  'mrc-1-001466': '1938년',
#  'mrc-0-004954': '제5중대장 김상흥 대위',
#  'mrc-0-004159': '해 (지지)단계',
#  'mrc-0-001235': '미치류의 화석',
#  'mrc-1-000813': '마리아나 제도에서 벗어나자',
#  'mrc-0-002445': '콘라트 2세',
#  'mrc-0-004336': '예루살렘 성전',
#  'mrc-0-001346': '호해',
#  'mrc-0-003364': '아우구스투스 시대',
#  'mrc-0-001891': '학업에 집중하기 위해',
#  'mrc-0-000033': '하난야',
#  'mrc-0-000201': '블라인드 테스트',
#  'mrc-0-003670': '구로야나기 테츠코',
#  'mrc-0-002224': '성장과 투자를 촉진하는 감세',
#  'mrc-0-000140': '다니엘 피셸체어',
#  'mrc-0-001124': '이희선',
#  'mrc-0-003870': '도시구',
#  'mrc-0-000386': '야즈데게르드 3세',
#  'mrc-0-005260': '마거리트 히긴스',
#  'mrc-0-004345': '2008',
#  'mrc-1-000376': '시나위 대금',
#  'mrc-0-001470': '쿠르브부아',
#  'mrc-1-000715': '마르키온',
#  'mrc-0-002747': '믈라카 술탄국',
#  'mrc-1-001341': '“가상 연좌시위”',
#  'mrc-0-003597': '브리튼섬 남부를 장악하여 속주로 삼을 때',
#  'mrc-0-003509': '미국 긴축정책',
#  'mrc-0-001335': '노예를 해방',
#  'mrc-0-004402': '1995년',
#  'mrc-1-001239': '차광막',
#  'mrc-1-000225': '2015년',
#  'mrc-0-003315': '보안',
#  'mrc-0-004971': '독일연방헌법재판소 재판관',
#  'mrc-0-004538': '밀',
#  'mrc-0-001940': '신라 경문왕',
#  'mrc-1-000573': '큰곰자리',
#  'mrc-0-005403': '2018년',
#  'mrc-0-002046': '모겐소',
#  'mrc-0-001943': '민간인',
#  'mrc-1-001141': '《후한서》',
#  'mrc-0-002709': '남자의 시체',
#  'mrc-0-000313': '2009년',
#  'mrc-0-003110': '메디차 가문',
#  'mrc-0-003155': '스카만드로스 강',
#  'mrc-1-001242': '볼바',
#  'mrc-0-004432': '영국',
#  'mrc-0-000755': '바위, 여자 아이에게는 구슬',
#  'mrc-1-001802': '호메이니',
#  'mrc-0-001241': '상업 분야',
#  'mrc-1-001457': '이성계',
#  'mrc-0-000016': '스윙',
#  'mrc-1-000695': '고려 말',
#  'mrc-1-000908': '기침',
#  'mrc-0-001034': '처벌',
#  'mrc-1-001735': '라스카리나 보볼리',
#  'mrc-1-001179': '쿠페',
#  'mrc-1-000521': '투르크메니스탄의 마리 근처',
#  'mrc-1-000623': '1866년',
#  'mrc-0-003953': '평균비용',
#  'mrc-0-002008': 'HA1 도메인의 18번 코돈',
#  'mrc-0-001699': '미터법',
#  'mrc-0-002374': '무로마치 막부',
#  'mrc-1-000086': '이승만',
#  'mrc-0-004490': '약물',
#  'mrc-1-000780': '강 노인',
#  'mrc-0-000037': '흥선대원군',
#  'mrc-0-003187': '외양간',
#  'mrc-1-000021': '국가안보상 필요할 경우',
#  'mrc-1-001634': '성경의 요한 계시록',
#  'mrc-1-000116': '프랑스 외교관',
#  'mrc-0-004669': '주교좌',
#  'mrc-0-002210': '분식점 종업원 이 모양(당시 18세)',
#  'mrc-0-004266': '영국',
#  'mrc-1-000862': '장괴',
#  'mrc-0-001884': '사랑',
#  'mrc-0-003249': '노르웨이',
#  'mrc-0-001728': '약 12,000명',
#  'mrc-0-000986': '헤수스 마리아 페레다',
#  'mrc-0-000970': '고천제',
#  'mrc-0-004182': '파시즘',
#  'mrc-0-003970': '센리 선',
#  'mrc-0-004626': '속엉덩동맥',
#  'mrc-0-000065': '1,668만 5천 달러',
#  'mrc-0-003016': '신춘문예공모전',
#  'mrc-0-000304': '1968년',
#  'mrc-0-003205': '18세기',
#  'mrc-0-002169': '다케다 한시(武田範之)',
#  'mrc-0-002771': '보이저 탐사선',
#  'mrc-0-003359': '모자',
#  'mrc-1-000666': '여름',
#  'mrc-0-003123': '세르비아군',
#  'mrc-0-003614': '생식샘',
#  'mrc-1-000791': '금융위원회',
#  'mrc-1-001485': '에베소',
#  'mrc-1-001025': '사학교',
#  'mrc-0-003425': '3차원',
#  'mrc-0-002676': '아루에',
#  'mrc-0-001432': '선조 이전',
#  'mrc-1-001332': '지미 제이미슨(Jimi Jamison)',
#  'mrc-0-001281': '사법부',
#  'mrc-0-003224': '91 cm 구경의 굴절망원경',
#  'mrc-0-000496': '5월 11일',
#  'mrc-0-001384': '미술',
#  'mrc-0-003067': '미국',
#  'mrc-0-004545': '중군',
#  'mrc-0-004460': '동료의 오인사격',
#  'mrc-0-002975': '엘디아 제국',
#  'mrc-0-004389': '트루먼의 아빠',
#  'mrc-0-005180': 'Lea et al (1987)',
#  'mrc-0-001374': '1309년',
#  'mrc-0-000431': '자기장',
#  'mrc-0-001783': '토마스 루드웰 리',
#  'mrc-0-000359': '연합국',
#  'mrc-0-002967': '이라크',
#  'mrc-0-001838': '1774년',
#  'mrc-0-000021': '1862년',
#  'mrc-0-004709': '블랙홀',
#  'mrc-0-003085': '80~90%',
#  'mrc-0-005332': '백제금동대향로',
#  'mrc-1-001594': '자동송환',
#  'mrc-1-000856': '선로 용량을 늘리기 위해',
#  'mrc-0-003629': '유성생식',
#  'mrc-0-005210': '네네',
#  'mrc-0-002685': '1876년',
#  'mrc-0-002938': '찰스 디 페소 (Charles C. Di Peso)',
#  'mrc-0-002936': '소비에트 연방',
#  'mrc-0-002389': '유교문화',
#  'mrc-0-003706': '천공',
#  'mrc-0-001366': '신성 로마 제국',
#  'mrc-0-005387': '서울대병원',
#  'mrc-0-003100': '히브리 백성이 황금 황소상',
#  'mrc-0-001021': '투사체의 궤적',
#  'mrc-0-000898': '이회창',
#  'mrc-1-000256': '아레델',
#  'mrc-0-001382': '그리스',
#  'mrc-0-004932': '3년',
#  'mrc-1-000008': '히틀러의 외투',
#  'mrc-0-002723': '주민등록지',
#  'mrc-0-005465': '쿠파',
#  'mrc-0-003236': '프로이센',
#  'mrc-0-003365': '비공식 굿즈',
#  'mrc-0-002788': '합작 5원칙',
#  'mrc-1-000582': '마음의 양식',
#  'mrc-0-001379': '산마리노',
#  'mrc-0-001445': '1960년 초반 아프리카인들의 독립 이전',
#  'mrc-0-000345': '조순형 의원',
#  'mrc-0-002584': '정규 공간',
#  'mrc-0-004928': '하미드 카르자이',
#  'mrc-0-004803': '예시 아티드랑 텔렘당',
#  'mrc-0-004927': '풍력이나 조력 발전 등 대체 에너지의 개발',
#  'mrc-1-000536': '보수적 거래로 양극화 되는 경향',
#  'mrc-0-002424': '포교성성(布敎聖省, Sacra Congregatio de Propaganda Fide)',
#  'mrc-0-000576': '하인리히 힘러',
#  'mrc-0-002786': '주총리',
#  'mrc-0-000205': '백선엽',
#  'mrc-0-002518': '3040세대',
#  'mrc-0-005293': '유니언역',
#  'mrc-1-001027': '광주지방검찰청 순천지청',
#  'mrc-0-001105': '키니코스 학파',
#  'mrc-0-000122': '종신형',
#  'mrc-0-000712': '포토맥군',
#  'mrc-0-001896': '스페셜라이즈드의 P 시리즈',
#  'mrc-0-003227': '대구',
#  'mrc-0-002215': '따끄옥루앗',
#  'mrc-0-002601': '네덜란드의 1, 2도시',
#  'mrc-0-004910': '유럽의 서부 전선',
#  'mrc-0-002166': '하루',
#  'mrc-0-003503': '긴급 구호 건설 법령',
#  'mrc-0-001845': '조봉암',
#  'mrc-0-001887': '고려시대',
#  'mrc-0-000316': 'M1 소총',
#  'mrc-0-003027': '리비우스',
#  'mrc-0-005283': '초음속의 빠른 속도로 진행되는 `격렬한 연소`',
#  'mrc-1-001543': '죽음의 트라이앵글(Triunghiul morții 트리운기울 모르치)',
#  'mrc-0-002338': '루피',
#  'mrc-0-002231': '바이스',
#  'mrc-0-002983': '초등학교 교원',
#  'mrc-0-004017': '정원 초과',
#  'mrc-0-001220': '4점',
#  'mrc-0-002746': '아칸바로',
#  'mrc-0-002285': '열적작용',
#  'mrc-0-001844': '키릴 문자',
#  'mrc-1-001797': '강화부',
#  'mrc-0-002028': '리을설(李乙雪, 1921-2015)',
#  'mrc-0-003031': '태종',
#  'mrc-1-001020': '소련',
#  'mrc-0-001574': '피오렐로 라과디아',
#  'mrc-1-000155': '지난 24일',
#  'mrc-1-000801': '손가락',
#  'mrc-0-003959': '스파르타의 장군 길리포스',
#  'mrc-1-000235': '농지',
#  'mrc-0-002716': '≪지에코초≫',
#  'mrc-0-000014': '유대인',
#  'mrc-0-000246': '톰 디마르코',
#  'mrc-0-003961': '스기타 겐파쿠',
#  'mrc-0-001030': '1988년',
#  'mrc-1-001600': '커비',
#  'mrc-1-001721': '아빠',
#  'mrc-1-000727': '두 가지',
#  'mrc-0-004738': '헌법 제37조 2항',
#  'mrc-1-001584': '텔루라이드 기숙사',
#  'mrc-1-000387': '편집 팀들',
#  'mrc-1-001370': '국제법',
#  'mrc-1-000621': '석굴암 유적',
#  'mrc-0-001557': '아테네',
#  'mrc-0-000850': '문장원',
#  'mrc-0-001149': '오키나와어',
#  'mrc-0-000288': '《작가의 일기》',
#  'mrc-1-001690': '국립중앙박물관',
#  'mrc-1-001603': '법관 출신 인사',
#  'mrc-0-004363': '파비아',
#  'mrc-0-000177': '8명',
#  'mrc-0-002514': 'API',
#  'mrc-0-001487': '85번',
#  'mrc-0-001961': '초속 46m의 바람',
#  'mrc-0-001938': '코네티컷 소년원',
#  'mrc-1-001692': '15개',
#  'mrc-0-003356': '언더우드(Underwood)박사',
#  'mrc-0-000574': '1954년',
#  'mrc-0-004196': '인격성',
#  'mrc-1-001541': '유대인',
#  'mrc-1-000550': '마리아의 다섯 가지 기쁨',
#  'mrc-1-000769': '한국군',
#  'mrc-0-003442': '악',
#  'mrc-0-000114': '채권자(갑)',
#  'mrc-0-002868': '1875년',
#  'mrc-0-002997': '1784년',
#  'mrc-0-002848': '잭',
#  'mrc-1-000889': '금산전투',
#  'mrc-1-000267': '지하 1층',
#  'mrc-0-002654': '한글판',
#  'mrc-0-001363': '찰스 2세',
#  'mrc-0-002282': '빌 맥코맥(Bill McCormack)',
#  'mrc-1-001592': '아침 시간대',
#  'mrc-1-000013': '별망성지',
#  'mrc-0-003170': '1994년',
#  'mrc-0-002758': '우크라이나',
#  'mrc-1-001310': '안티트롬빈',
#  'mrc-1-001545': '완하제',
#  'mrc-1-001727': '부산 해안',
#  'mrc-0-004755': '프레쉬킬스 매립',
#  'mrc-1-001035': '절',
#  'mrc-0-000687': '5건',
#  'mrc-0-003514': '스페인 군대',
#  'mrc-0-004484': '전라남도 지역',
#  'mrc-0-004310': '일본 가도카와 쇼텐',
#  'mrc-0-002525': '<<종횡무진 한국경제>>',
#  'mrc-0-004855': '1776년',
#  'mrc-0-001847': '호해',
#  'mrc-0-003215': '1939년',
#  'mrc-0-000328': '사실주의',
#  'mrc-0-002947': '르네상스 양식',
#  'mrc-0-001757': '《The Story of M4》',
#  'mrc-0-001778': '1045년',
#  'mrc-0-002720': '하후상',
#  'mrc-0-003413': '스톤페리어',
#  'mrc-0-004594': '중장기적 인구감소',
#  'mrc-0-001133': '언카스(또는 다운카스, Uncas)',
#  'mrc-1-000320': '해동의 예도 검법 1번 ~ 9번',
#  'mrc-0-003669': '다저스',
#  'mrc-1-001443': '일리노이주',
#  'mrc-0-004862': '정통 칼리파(Al-Khalifah Ar-Rashid)',
#  'mrc-1-001549': '경추 손상',
#  'mrc-0-003821': '카르도나',
#  'mrc-0-002832': '무릎인대 부상',
#  'mrc-1-000691': '에우메네스',
#  'mrc-0-001607': '스렝',
#  'mrc-0-003454': '16세기',
#  'mrc-0-000206': '안사의 난',
#  'mrc-0-001179': '소프트웨어 엔지니어링',
#  'mrc-0-003043': '유니버설 뮤직',
#  'mrc-0-004648': '간이나 비장의 비대증',
#  'mrc-0-003434': '보육·노동 관련 정책을 정부에 제시하는 활동',
#  'mrc-0-002074': '30분',
#  'mrc-1-000580': '윤치호',
#  'mrc-0-005097': '갈리아인',
#  'mrc-0-001324': '서울특별시',
#  'mrc-0-002816': '문학 혁명',
#  'mrc-0-000895': '양서류',
#  'mrc-0-002127': '4막 3장이',
#  'mrc-0-002436': '오스트리아-헝가리 제국 시대',
#  'mrc-0-002265': '1935년',
#  'mrc-0-003068': '시구르드',
#  'mrc-0-001438': '쌍계사',
#  'mrc-0-001072': '새누리당',
#  'mrc-0-002927': '12척',
#  'mrc-0-000028': '항공기 조종사',
#  'mrc-1-000292': '오티스 소프',
#  'mrc-0-001415': '알샤바브 요원이었던 경호원',
#  'mrc-0-000499': '쿠로시오 해류',
#  'mrc-1-000650': '정결한 것과 부정한 것',
#  'mrc-0-000780': '',
#  'mrc-1-001635': '배우자',
#  'mrc-0-003105': '건축',
#  'mrc-0-001689': '1671년',
#  'mrc-0-002170': '〈친일파 군상〉',
#  'mrc-0-000964': '하리수',
#  'mrc-0-002414': '국부 부분',
#  'mrc-0-000668': '북부 아크로폴리스 33번 신전 아래',
#  'mrc-0-003544': '프랑스',
#  'mrc-0-002033': '급진파 파시스트',
#  'mrc-1-000189': '공수부대',
#  'mrc-0-003180': '한스 칼 폰 빈터펠트 장군',
#  'mrc-1-001214': 'CP0의 요원',
#  'mrc-0-004245': '외무대신',
#  'mrc-1-001689': '아리엘 샤론',
#  'mrc-0-002777': '《Brothers and Sisters》',
#  'mrc-1-001394': '바라아',
#  'mrc-1-001716': '1945년',
#  'mrc-0-002979': '5칸',
#  'mrc-0-002493': '야마가타현',
#  'mrc-0-002092': '「소방공무원법」',
#  'mrc-0-002536': '다니엘 슈타이벨트',
#  'mrc-0-002219': '위험한 물질',
#  'mrc-1-001196': '다케다 요헤이',
#  'mrc-0-004690': '허예은선수',
#  'mrc-0-002045': '허버트 헌팅턴 휘틀리(Herbert Huntington-Whiteley)',
#  'mrc-0-002879': '피렌체',
#  'mrc-0-003617': '트로츠키',
#  'mrc-0-002618': '태황제',
#  'mrc-0-001614': '1970년대 이후',
#  'mrc-0-004674': '테코아쿠',
#  'mrc-0-000393': '10대 시절',
#  'mrc-0-003645': '14번 사중주 올림가단조',
#  'mrc-0-001272': '포항교도소',
#  'mrc-0-000740': '학습자가 정보 통달에 이를 때',
#  'mrc-0-003639': '동사 어근',
#  'mrc-0-003904': '1922년',
#  'mrc-0-005094': '여성 금주 동맹',
#  'mrc-0-005209': '노름판',
#  'mrc-0-003716': '오스트리아',
#  'mrc-0-004081': '세계 최대의 해류',
#  'mrc-0-001180': '1811년',
#  'mrc-0-001046': '프랭클린 D. 루스벨트',
#  'mrc-0-001863': '학업 기준',
#  'mrc-0-003926': '살아남은 조카들',
#  'mrc-0-000500': '2019년',
#  'mrc-0-001654': '토지 100,147평(부산 서면 지역)',
#  'mrc-0-001123': '치안업무',
#  'mrc-1-000056': '라크스 클라인',
#  'mrc-0-000852': '틀린 것(error)',
#  'mrc-0-003331': '200만 달러',
#  'mrc-1-001071': '남자아이 빈을 데려다 양자로 삼는다',
#  'mrc-0-001192': '황교안 법무부 장관',
#  'mrc-0-005108': '에로스',
#  'mrc-0-004329': '황소',
#  'mrc-1-001425': '260억 개',
#  'mrc-1-001769': '중국 상나라',
#  'mrc-0-002916': '레버를 낮추는 것만으로 선반에 놓인 술 병을 하수 시스템에 흘린다는 시스템',
#  'mrc-0-000435': '젊은이들',
#  'mrc-1-001269': '패닌',
#  'mrc-0-000459': '이자성',
#  'mrc-1-000713': '데니소바 동굴',
#  'mrc-1-000218': '보러블 3부작',
#  'mrc-0-004970': '한 번',
#  'mrc-1-000690': '에릭 스타보 골트',
#  'mrc-0-003499': '초음파 가습기',
#  'mrc-1-000181': '요외르크 젠하이저',
#  'mrc-0-003996': '토우야',
#  'mrc-0-004708': '위장',
#  'mrc-0-005410': '오미이마즈 역',
#  'mrc-0-004579': '서대문',
#  'mrc-0-001793': '플라티니',
#  'mrc-0-000255': '실권',
#  'mrc-0-001705': '슈베르트',
#  'mrc-0-001539': '목포',
#  'mrc-1-001624': '가즈사 국',
#  'mrc-1-000694': '킹 윌리엄스 학교',
#  'mrc-0-001425': '중심지 이동설',
#  'mrc-1-001516': '가속화 분류기',
#  'mrc-1-000954': '1989년',
#  'mrc-0-005166': '괜찮',
#  'mrc-0-000096': '2009년 8월',
#  'mrc-0-003596': '부당한 일요등교 지시',
#  'mrc-0-002651': '캐나다',
#  'mrc-0-001370': '해태전자',
#  'mrc-0-002766': '1969년',
#  'mrc-0-000150': '2-1',
#  'mrc-0-000760': '공개 프록시',
#  'mrc-1-000870': 'Needles and Pins',
#  'mrc-1-001011': '뷔르츠부르크 대학교',
#  'mrc-1-000112': '순치제',
#  'mrc-0-004510': '인체의 치수',
#  'mrc-1-001436': '앙리 블랑슈',
#  'mrc-0-002482': '근원 마그마가 형성되는 기작',
#  'mrc-0-000527': '과학',
#  'mrc-0-004840': '사람들의 기질이 나쁘므로',
#  'mrc-0-001931': '남서부 전선군',
#  'mrc-0-004832': '공병우 자판',
#  'mrc-1-001729': '수리물리학',
#  'mrc-0-000866': '1945년',
#  'mrc-1-000278': '정반합지양(正反合止揚)시키는 방법',
#  'mrc-0-000723': '빛',
#  'mrc-0-000942': '모터크로스 레이서',
#  'mrc-0-004280': '사츠키',
#  'mrc-1-000518': '아드레날린',
#  'mrc-0-004371': '존 브록만',
#  'mrc-1-001582': '1887년',
#  'mrc-0-002164': '《완전한 죽음》',
#  'mrc-0-001076': '베다',
#  'mrc-0-003962': '뉴질랜드',
#  'mrc-1-000094': '구와바라 다케오(桑原武夫, 교토대 명예교수)',
#  'mrc-1-001301': '대통령 캘빈 쿨리지',
#  'mrc-0-002763': '강릉',
#  'mrc-0-001429': '제노바 공화국',
#  'mrc-1-000651': '호림박물관',
#  'mrc-0-004649': '내각',
#  'mrc-0-004438': '실험',
#  'mrc-0-005422': '몸',
#  'mrc-0-000845': '오삼계',
#  'mrc-0-002188': '글루탐산이 아스파르트산',
#  'mrc-0-003648': '상대적 손실 가치',
#  'mrc-0-003069': '블루 라인',
#  'mrc-0-004759': '하이브리드 잉크 배합물',
#  'mrc-1-000412': '미하일린',
#  'mrc-0-001078': '2016년',
#  'mrc-0-000394': '부장급',
#  'mrc-0-002289': '남해안 일대 요충지',
#  'mrc-0-000734': '언더우드 박사 집',
#  'mrc-1-000770': '중동 건설 현장',
#  'mrc-0-004187': '승려',
#  'mrc-1-001554': '야기옐론 대학',
#  'mrc-0-000062': '전달판',
#  'mrc-0-003460': '에피폴라이 대지 근처',
#  'mrc-0-003038': '테쿰세',
#  'mrc-0-001682': '무죄',
#  'mrc-0-001457': '신라',
#  'mrc-1-000143': '뉴어크 아카데미(현재 델라웨어 대학교)',
#  'mrc-0-003755': '무신',
#  'mrc-0-001393': '마이클 뉴먼',
#  'mrc-0-001790': '스카버러 타운 센터',
#  'mrc-0-003418': '티베트인들',
#  'mrc-0-002696': '1948년',
#  'mrc-0-004465': '와히드 박사',
#  'mrc-0-002840': '화이트워터 사건',
#  'mrc-1-000972': '미노프스키 입자',
#  'mrc-1-000227': '동탁군',
#  'mrc-0-002155': '일본의 문예춘추',
#  'mrc-0-000564': '1970년',
#  'mrc-0-001660': '3미터',
#  'mrc-0-004323': '항만 노동자',
#  'mrc-0-000664': '에리크 악셀 에릭손(Erik Axel Eriksson)',
#  'mrc-0-000913': '탈당',
#  'mrc-0-004373': '5월 29일',
#  'mrc-0-004392': '뇌',
#  'mrc-1-001229': '교황 요한 바오로 2세',
#  'mrc-0-005342': '소루트비히',
#  'mrc-0-000030': '‘일시루(一是樓)’',
#  'mrc-0-002098': '베리와 부르봉 분가들',
#  'mrc-0-000162': '스타베크 포트발 크빈네르',
#  'mrc-0-000784': '프랑스',
#  'mrc-0-004040': '안티오쿠스',
#  'mrc-1-001277': '좀비',
#  'mrc-0-000434': '티코 브라헤에 관한 15권 분량의 저서 “오페라 옴니아”를 편집하고자',
#  'mrc-0-002096': '1910년',
#  'mrc-0-001878': '법주사',
#  'mrc-0-000211': '홍콩 기업 리앤풍의 자회사인 BLS코리아',
#  'mrc-0-004085': '알란 맥켄',
#  'mrc-0-004909': '모술',
#  'mrc-0-003441': '1988년',
#  'mrc-0-003807': '생선',
#  'mrc-0-001026': '86 편',
#  'mrc-1-000524': '밀로셰비치',
#  'mrc-0-001864': '나나 아쿠포아',
#  'mrc-0-004467': '2012년',
#  'mrc-0-002636': '1977년',
#  'mrc-0-004710': '공훈의 보상',
#  'mrc-0-002581': '중앙위원회',
#  'mrc-0-005012': '이탈리아 요리',
#  'mrc-0-003040': '일본',
#  'mrc-0-003558': '연방 정부',
#  'mrc-1-001670': '계자난간',
#  'mrc-0-004531': '판옥선',
#  'mrc-0-003835': '토스카나',
#  'mrc-0-002683': '1649년(인조 27)',
#  'mrc-0-003770': '명련사',
#  'mrc-0-003053': '군사위원회',
#  'mrc-1-001426': '12마일 전관수역 주장',
#  'mrc-0-002782': '명종',
#  'mrc-0-002245': '레드훅 스튜디오',
#  'mrc-0-004111': '1924년',
#  'mrc-1-001775': '위건 애슬레틱',
#  'mrc-0-002130': '아라크노포비아',
#  'mrc-1-001559': '대만총독부',
#  'mrc-1-000627': '1990년 1월',
#  'mrc-0-004672': '조운규(趙雲逵)',
#  'mrc-1-001051': '국제청소년물리토너먼트(IYPT)',
#  'mrc-1-001316': '조선무선공학원',
#  'mrc-1-000977': '돈의문 터',
#  'mrc-1-000788': '잉글랜드',
#  'mrc-0-002530': '안티오코스 3세',
#  'mrc-0-002481': '세 가지',
#  'mrc-0-000283': '비올라',
#  'mrc-0-003501': '백병계열군',
#  'mrc-0-003500': '단단한 신체 부위',
#  'mrc-0-004308': 'Beetles(딱정벌레)',
#  'mrc-1-000841': '한진창',
#  'mrc-1-001669': '부근 대밭골',
#  'mrc-0-005486': '조조',
#  'mrc-0-004372': '도쿄에 위치한 예하 본부',
#  'mrc-0-000944': '목재',
#  'mrc-0-004410': '프랑수아 드 라 로크',
#  'mrc-0-001659': '솔레놉신',
#  'mrc-0-002991': '아유미',
#  'mrc-0-001251': '공화당원 투표인들',
#  'mrc-0-003528': '어사대부',
#  'mrc-0-002877': '빌트루디스',
#  'mrc-1-000177': '제8조',
#  'mrc-0-005447': '석재',
#  'mrc-1-001517': '대만 순무',
#  'mrc-0-003711': '성철(이영주)',
#  'mrc-0-004394': '프리드리히 니체',
#  'mrc-0-004335': '일간 뉴욕타임스',
#  'mrc-0-000651': '1967년',
#  'mrc-0-002989': '재단 X',
#  'mrc-0-001804': '자유당계 인사들',
#  'mrc-0-003411': '초자연적 찬탈자',
#  'mrc-0-003436': '주노 해변',
#  'mrc-0-002605': '세라믹'}
